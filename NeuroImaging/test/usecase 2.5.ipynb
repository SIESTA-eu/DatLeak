# %% [markdown]
# In this notebook you'll find a range of tests showcasing how leakage is detected using our repostory. Different types of scrambling methods with different parameteres have been tested. The result is either visualized or reported at the bottom of the related test.
#
# ## Data
# This test is using a 4D fMRI image, that each time you run a test will be downloaded and deleted at the end. Read more about data in this [link](https://openneuro.org/datasets/ds004934/versions/1.0.0) which OpenNeuro is hosting.
#
# Each cell in this notebook is associated with different scrambling method and its parameters.
#
#
# ## Methods:
# We have tested the leakage score using three known methods.
# - [[Pearson correlation]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Pearson_correlation_coefficient&ved=2ahUKEwic1fmek9KNAxVp2QIHHef7MlIQFnoECDMQAQ&usg=AOvVaw0oS2sNVkApYvcS_BsC8s3p): A mathematical correlation coefficient representing the relationship between one 2D slice of original vs. corresponding scrambled 2D slice.
# - Structural Similarity Index Measure[[SSIM]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Structural_similarity_index_measure&ved=2ahUKEwjWrMKvktKNAxUR1QIHHcsFMcsQFnoECBAQAQ&usg=AOvVaw0DeKf5zozxPyKboaovBeRN): A perceptual metric that quantifies image quality degradation caused by scrambling.
# - Identical[[np.allclose]](https://numpy.org/doc/2.1/reference/generated/numpy.allclose.html): Searches for exact identical arrays of voxels
# ## What to expect:
# - We increase the intensity of different scrambling methods and run our leakage detection method, thus we expect to see less leakage as intensity increases.
# - At the bottom of each test, we visualize either plots to track leakage or a report inlcuding basic descriptive statistics with distribution plots.
# - The x-axis in the plots shows scrambling parameter, and y-axis shows leakage score.
#
# ## List of tests:
# - Original Vs. Original
# - Permutation
# - Wobble
# - Scatter
# - Blur

# %%
import os, sys, subprocess, csv, random, wget, shutil
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt

# %%
def viz(f, crit): 
    pl = [float(x[0]) for x in f]
    fl = [int(x[1]) for x in f]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    ax1.plot(list(crit),pl, color='skyblue')
    ax1.set_title("Partial Leakage")
    ax1.set_xlabel("Scrambling parameter")
    ax1.set_ylabel("Leakage score")
    ax2.plot(list(crit),fl, color='skyblue')
    ax2.set_title("Full Leakage")
    ax2.set_xlabel("Scrambling parameter")
    
    plt.tight_layout()
    plt.show()

def run_test(files=list, opt=list, scramble=True, clean=True, disp=False):
    
    os.makedirs("img", exist_ok=True)
    link_original = "https://s3.amazonaws.com/openneuro.org/ds004934/sub-SAXNES2s001/func/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz?versionId=R0fwRS9fxw8CcPZnb4zYsw9I5v19aAbP"
    wget.download(link_original)
    os.makedirs("input/func/original", exist_ok=True)
    file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()) for file in files if file.endswith(".gz")]
    shutil.copy2(file_[0], "input/func/original")
    os.remove(file_[0])
    print(f"\nOriginal file downloaded.")
    script = os.path.join(os.path.dirname(os.getcwd()), "run_test.py")
    original = files[0]
    scrambled = files[1]
    params = {
        "input": original,
        "output": scrambled,
        "opts": opts
    }
    if scramble:
        ! scramble "{params['input']}" "{params['output']}" {" ".join(params['opts'])}
    print(f"Original file is scrambled.")
    result= subprocess.run(
        ["python3", script, original, scrambled, "True"],
        capture_output=True,
        text=True
    )
    print(result.stdout)
    print(f"Analysis is finished.")
    if disp:
        file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()+"/report/") for file in files if file.endswith(".html")]
        with open(file_[0]) as f:
            display(HTML(f.read()))
       
    if clean:
        print(f"Cleaning up ...") 
        ! rm -r input report img

# %% [markdown]
# # Original Vs. Original
# We test the same original image and we expect to see full leakage.
#
# For more details, we can check the visualization where you can see the distribution of identicals.
# ## What to expect:
# We expect to see identified full leakage since both images are similar

# %%
original = "input/func/original/"
scrambled = "input/func/scrambled/"
opts = ["nii", "permute", "x -i"] # this will NOT be used in this cell, but need to pass
files = [original, original]
run_test(files, scramble=False, clean=False, disp=True) # NOTE: If original vs. original, then clean=False, otherwise original file gets deleted.
! rm result.tsv
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 69/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 70/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 50/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 241095/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> True</p>
#                 <p><strong>Partial leakage:</strong> 100.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.09&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.47</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.50</p>
#                     <p><strong>Z</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.44</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.38</p>
#                     <p><strong>Y</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.45</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.39</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">SpatioTemporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="SpatioTemporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>

# %% [markdown]
# # Method: Permutation
# In this case we **permute** the image to see how scramble affect the leakage.
# Permutation is done in two different ways.
#
# - Independently where we pass **-i** as argument, which all arrays in the given axis are permuted independently.
# - Without **-i** the given axis remain as it is, while other axis are permuted.
#
# We test permutation on each axis w/o passing **-i** as argument

# %%
! rm result.tsv
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
opts = ["nii", "permute", 
        [["x -i"], ["y -i"], ["z -i"], ["t -i"], ["x"], ["y"], ["z"], ["t"]]] 

for i in opts[2]:
    link_original = "https://s3.amazonaws.com/openneuro.org/ds004934/sub-SAXNES2s001/func/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz?versionId=R0fwRS9fxw8CcPZnb4zYsw9I5v19aAbP"
    wget.download(link_original)
    os.makedirs("input/func/original", exist_ok=True)
    file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()) for file in files if file.endswith(".gz")]
    shutil.copy2(file_[0], "input/func/original")
    os.remove(file_[0])
    opt_ = " ".join([opts[0], opts[1], i[0]]).split(" ")
    ! scramble "{files[0]}" "{files[1]}" {" ".join(opt_)}
    print(" ".join(opt_))
    run_test(files, opt=opt_, clean=True, scramble=False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,[i[0] for i in opts[2]])
! rm result.tsv
# Out:
# rm: cannot remove 'result.tsv': No such file or directory
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute x -i                                                                40s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.49
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.3
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.38
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.4605
#  - Partial Leakage: 0.39
#  - Full Leakage: False
#
# Total time taken: 00:00:39
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute y -i                                                                32s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.37
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.59
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.42
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.332
#  - Partial Leakage: 0.46
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute z -i                                                                33s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.26
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.39
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.51
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.2997
#  - Partial Leakage: 0.39
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute t -i                                                                99s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.3375
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute x                                                                   69s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 69/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.29
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.38
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 3313/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.56
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute y                                                                   81s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.36
# 	 - Dimension[Y]: 	Full Leakage: 70/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.38
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 3030/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.58
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute z                                                                   36s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.39
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.46
# 	 - Dimension[Z]: 	Full Leakage: 50/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9793
#  - Partial Leakage: 0.62
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute t                                                                   62s/file]
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.3042
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:42
#
# Analysis is finished.
# Cleaning up ...

# %% [markdown]
# This is the same exact test as prevoius one, along permutaion independently only on time-axis with report.
#
# ## What to expect:
# In the report you can see the distribution plots of this test for more details, alongside minimum, maximum and average leakage along each axis. We expect to see in the plots **n** number of images which is identical to the original image, since slices are replaced from original.

# %%
! rm result.tsv
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
opts = ["nii", "permute", "t -i"] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# rm: cannot remove 'result.tsv': No such file or directory
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     99s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.3004
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> True</p>
#                 <p><strong>Partial leakage:</strong> 100.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.09&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.47</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.50</p>
#                     <p><strong>Z</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.44</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.38</p>
#                     <p><strong>Y</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.45</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.39</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">SpatioTemporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="SpatioTemporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Wobble
# Deform the images using 3D random waveforms
#
# ## What to expect:
# We expect lesser leakage as the intensity of wobbling is higher.
#
# At the bottom, we visualize the result of **full** and **partial leakage** where x-axis shows the wobbling intensity and y-axis is leakage

# %%
! rm result.tsv
opts = ["nii", "wobble", "-a ", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 
crit = np.arange(2.0, 12.5, 0.5, dtype=float)

for p in crit:
    opts[3] = str(p)
    print(opts)
    run_test(files, opt=opts, clean= False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# ['nii', 'wobble', '-a ', '2.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     86s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.36
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.4
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.37
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 20/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.38
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:40
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '2.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     40s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.29
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.27
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.28
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 14/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.28
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '3.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     57s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.2
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.23
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.24
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 2/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.22
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '3.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     94s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.14
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.16
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.17
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 5/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.16
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '4.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     07s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.12
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.14
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.14
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.14
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '4.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     57s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.09
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.1
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.09
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 2/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.09
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '5.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     10s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.09
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.09
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.08
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 5/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.09
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '5.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     60s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.1
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.07
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 3/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.08
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '6.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     57s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.08
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.07
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.951
#  - Partial Leakage: 0.07
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '6.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     67s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '7.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     79s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.06
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9544
#  - Partial Leakage: 0.06
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '7.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     63s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.964
#  - Partial Leakage: 0.06
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '8.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     63s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.05
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.04
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 3/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '8.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     29s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '9.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     85s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.05
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9575
#  - Partial Leakage: 0.05
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '9.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     50s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.05
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '10.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     54s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.06
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '10.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     44s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.06
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9456
#  - Partial Leakage: 0.06
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '11.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     66s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.05
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.05
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '11.5']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     54s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.07
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.04
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.05
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '12.0']
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     82s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.05
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.06
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.07
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 1/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.06
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.

# %%
opts = ["nii", "wobble", "-a ", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     56s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.1
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.09
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.08
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.977
#  - Partial Leakage: 0.09
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 9.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: -0.05&emsp;&emsp;&emsp;Max: 0.10&emsp;&emsp;&emsp;AVG: 0.02</p>
#                     <p><strong>Y</strong>: Min: -0.04&emsp;&emsp;&emsp;Max: 0.09&emsp;&emsp;&emsp;AVG: 0.03</p>
#                     <p><strong>Z</strong>: Min: -0.02&emsp;&emsp;&emsp;Max: 0.08&emsp;&emsp;&emsp;AVG: 0.04</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: -0.03&emsp;&emsp;&emsp;Max: 0.10&emsp;&emsp;&emsp;AVG: 0.03</p>
#                     <p><strong>Y</strong>: Min: -0.02&emsp;&emsp;&emsp;Max: 0.10&emsp;&emsp;&emsp;AVG: 0.04</p>
#                     <p><strong>Z</strong>: Min: -0.00&emsp;&emsp;&emsp;Max: 0.09&emsp;&emsp;&emsp;AVG: 0.04</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">SpatioTemporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="SpatioTemporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Method: Scatter

# %%
! rm result.tsv
opts = ["nii", "scatter", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
crit = np.arange(3, 13.5, 0.5, dtype=float)

for p in crit:
    opts[2] = str(p)
    run_test(files, opt=opts, clean= True)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 1]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     21s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.89
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.91
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.99
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4655/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.93
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     70s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.78
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.8
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.99
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4655/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.86
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     04s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.78
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.81
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.99
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4655/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.86
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     27s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.66
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.71
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4587/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.78
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     44s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.57
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.61
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4587/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.72
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     88s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.57
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.61
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4587/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.72
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 3]                                                                  ?file/s]
# step: [2, 2, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     98s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.97
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 13863/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.99
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 3]                                                                  ?file/s]
# step: [2, 2, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     52s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.97
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 13863/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.99
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     93s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 18512/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     58s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.53
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.57
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 9480/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.7
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     29s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.53
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.57
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 9480/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.7
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 5]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     69s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.46
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.51
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.55
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4492/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.51
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 5]                                                                  ?file/s]
# step: [3, 3, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     92s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.5
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.54
# 	 - Dimension[Z]: 	Full Leakage: 1/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4871/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.68
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 5]                                                                  ?file/s]
# step: [3, 3, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     04s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.5
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.54
# 	 - Dimension[Z]: 	Full Leakage: 1/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4871/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.68
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     29s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.48
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.53
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 9519/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.67
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     37s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 22937/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     56s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 22937/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     39s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 3/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 2/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 22937/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     70s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 1/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 14131/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     18s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 1/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 14131/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     49s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 2/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 1/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 14131/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# Cleaning up ...

# %%
opts = ["nii", "scatter", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     48s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.57
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.61
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 4587/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 0.72
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> True</p>
#                 <p><strong>Partial leakage:</strong> 72.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 0.57&emsp;&emsp;&emsp;AVG: 0.28</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 0.61&emsp;&emsp;&emsp;AVG: 0.37</p>
#                     <p><strong>Z</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.36</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 0.57&emsp;&emsp;&emsp;AVG: 0.23</p>
#                     <p><strong>Y</strong>: Min: 0.03&emsp;&emsp;&emsp;Max: 0.61&emsp;&emsp;&emsp;AVG: 0.33</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.31</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">SpatioTemporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="SpatioTemporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Blur
# Applies a 3D Gaussian smoothing filter. This method removes details and noise to blur the image.
#
# ## What to expect:
# We expect to see less partial leakage as the intensity of the blurring increases, and perhaps full leakage when blurring is at the lowest level.

# %%
! rm result.tsv
opts = ["nii", "blur", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 
crit = np.arange(2.0, 12.0, 1.0, dtype=float)

for p in crit:
    opts[2] = str(p)
    run_test(files, opt=opts, clean= False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     47s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 56/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 70/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 46/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 75191/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     67s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 1.0
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 1.0
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 1.0
#  - Partial Leakage: 1.0
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     73s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.99
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9996
#  - Partial Leakage: 0.99
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     78s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9989
#  - Partial Leakage: 0.99
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     70s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.98
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.98
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9978
#  - Partial Leakage: 0.98
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     76s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.97
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.97
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.97
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9968
#  - Partial Leakage: 0.97
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     16s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.97
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.97
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.97
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9959
#  - Partial Leakage: 0.97
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     13s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.96
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.96
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.96
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9946
#  - Partial Leakage: 0.96
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     35s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.95
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.96
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.96
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9939
#  - Partial Leakage: 0.96
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     13s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.95
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.95
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.95
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9929
#  - Partial Leakage: 0.95
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.

# %%
opts = ["nii", "blur", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [........................................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     86s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Partial Leakage: 0.99
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Partial Leakage: 0.98
#  - Spatiotemporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - SpatioTemporal: 	Full Leakage: 0/245000 voxels 	Partial Leakage 0.9989
#  - Partial Leakage: 0.99
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 99.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.09&emsp;&emsp;&emsp;Max: 0.99&emsp;&emsp;&emsp;AVG: 0.52</p>
#                     <p><strong>Y</strong>: Min: 0.14&emsp;&emsp;&emsp;Max: 0.99&emsp;&emsp;&emsp;AVG: 0.54</p>
#                     <p><strong>Z</strong>: Min: 0.07&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.48</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.03&emsp;&emsp;&emsp;Max: 0.97&emsp;&emsp;&emsp;AVG: 0.40</p>
#                     <p><strong>Y</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 0.97&emsp;&emsp;&emsp;AVG: 0.46</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.41</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">SpatioTemporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="SpatioTemporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...
