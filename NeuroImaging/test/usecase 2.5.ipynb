# %% [markdown]
# In this notebook you'll find a range of tests showcasing how leakage is detected using our repostory. Different types of scrambling methods with different parameteres have been tested. The result is either visualized or reported at the bottom of the related test.
#
# ## Data
# This test is using a 4D fMRI image, that each time you run a test will be downloaded and deleted at the end. Read more about data in this [link](https://openneuro.org/datasets/ds004934/versions/1.0.0) which OpenNeuro is hosting.
#
# Each cell in this notebook is associated with different scrambling method and its parameters.
#
#
# ## Methods:
# We have tested the leakage score using three known methods.
# - [[Pearson correlation]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Pearson_correlation_coefficient&ved=2ahUKEwic1fmek9KNAxVp2QIHHef7MlIQFnoECDMQAQ&usg=AOvVaw0oS2sNVkApYvcS_BsC8s3p): A mathematical correlation coefficient representing the relationship between one 2D slice of original vs. corresponding scrambled 2D slice.
# - Structural Similarity Index Measure[[SSIM]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Structural_similarity_index_measure&ved=2ahUKEwjWrMKvktKNAxUR1QIHHcsFMcsQFnoECBAQAQ&usg=AOvVaw0DeKf5zozxPyKboaovBeRN): A perceptual metric that quantifies image quality degradation caused by scrambling.
# - Identical[[np.allclose]](https://numpy.org/doc/2.1/reference/generated/numpy.allclose.html): Searches for exact identical arrays of voxels
# ## What to expect:
# - We increase the intensity of different scrambling methods and run our leakage detection method, thus we expect to see less leakage as intensity increases.
# - At the bottom of each test, we visualize either plots to track leakage or a report inlcuding basic descriptive statistics with distribution plots.
# - The x-axis in the plots shows scrambling parameter, and y-axis shows leakage score.
#
# ## List of tests:
# - Original Vs. Original
# - Permutation
# - Wobble
# - Scatter
# - Blur

# %%
import os, sys, subprocess, csv, random, wget, shutil
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt

# %%
def viz(f, crit): 
    pl = [float(x[0]) for x in f]
    fl = [int(x[1]) for x in f]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    ax1.plot(list(crit),pl, color='skyblue')
    ax1.set_title("Partial Leakage")
    ax1.set_xlabel("Scrambling parameter")
    ax1.set_ylabel("Leakage score")
    ax2.plot(list(crit),fl, color='skyblue')
    ax2.set_title("Full Leakage")
    ax2.set_xlabel("Scrambling parameter")
    
    plt.tight_layout()
    plt.show()

def run_test(files=list, opt=list, scramble=True, clean=True, disp=False):
    
    os.makedirs("img", exist_ok=True)
    link_original = "https://s3.amazonaws.com/openneuro.org/ds004934/sub-SAXNES2s001/func/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz?versionId=R0fwRS9fxw8CcPZnb4zYsw9I5v19aAbP"
    wget.download(link_original)
    os.makedirs("input/func/original", exist_ok=True)
    file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()) for file in files if file.endswith(".gz")]
    shutil.copy2(file_[0], "input/func/original")
    os.remove(file_[0])
    print(f"\nOriginal file downloaded.")
    script = os.path.join(os.path.dirname(os.getcwd()), "run_test.py")
    original = files[0]
    scrambled = files[1]
    params = {
        "input": original,
        "output": scrambled,
        "opts": opts
    }
    if scramble:
        ! scramble "{params['input']}" "{params['output']}" {" ".join(params['opts'])}
    print(f"Original file is scrambled.")
    result= subprocess.run(
        ["python3", script, original, scrambled, "True"],
        capture_output=True,
        text=True
    )
    print(result.stdout)
    print(f"Analysis is finished.")
    if disp:
        file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()+"/report/") for file in files if file.endswith(".html")]
        with open(file_[0]) as f:
            display(HTML(f.read()))
       
    if clean:
        print(f"Cleaning up ...") 
        ! rm -r input report img

# %% [markdown]
# # Original Vs. Original
# We test the same original image and we expect to see full leakage.
#
# For more details, we can check the visualization where you can see the distribution of identicals.
# ## What to expect:
# We expect to see identified full leakage since both images are similar

# %%
original = "input/func/original/"
scrambled = "input/func/scrambled/"
opts = ["nii", "permute", "x -i"] # this will NOT be used in this cell, but need to pass
files = [original, original]
run_test(files, scramble=False, clean=False, disp=True) # NOTE: If original vs. original, then clean=False, otherwise original file gets deleted.
! rm result.tsv
# Out:
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 69/70 slices	Average Partial Leakage: Null
# 	 - Dimension[Y]: 	Full Leakage: 70/70 slices	Average Partial Leakage: Null
# 	 - Dimension[Z]: 	Full Leakage: 50/50 slices	Average Partial Leakage: Null
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 241095/245000 voxels 	Average Partial Leakage Null
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> True</p>
#                 <p><strong>Partial leakage:</strong> 100.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.09&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.47</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.50</p>
#                     <p><strong>Z</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.44</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.38</p>
#                     <p><strong>Y</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.45</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.39</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">Temporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Temporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>

# %% [markdown]
# # Method: Permutation
# In this case we **permute** the image to see how scramble affect the leakage.
# Permutation is done in two different ways.
#
# - Independently where we pass **-i** as argument, which all arrays in the given axis are permuted independently.
# - Without **-i** the given axis remain as it is, while other axis are permuted.
#
# We test permutation on each axis w/o passing **-i** as argument

# %%
! rm result.tsv
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
opts = ["nii", "permute", 
        [["x -i"], ["y -i"], ["z -i"], ["t -i"], ["x"], ["y"], ["z"], ["t"]]] 

for i in opts[2]:
    link_original = "https://s3.amazonaws.com/openneuro.org/ds004934/sub-SAXNES2s001/func/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz?versionId=R0fwRS9fxw8CcPZnb4zYsw9I5v19aAbP"
    wget.download(link_original)
    os.makedirs("input/func/original", exist_ok=True)
    file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()) for file in files if file.endswith(".gz")]
    shutil.copy2(file_[0], "input/func/original")
    os.remove(file_[0])
    opt_ = " ".join([opts[0], opts[1], i[0]]).split(" ")
    ! scramble "{files[0]}" "{files[1]}" {" ".join(opt_)}
    print(" ".join(opt_))
    run_test(files, opt=opt_, clean=True, scramble=False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,[i[0] for i in opts[2]])
! rm result.tsv
# Out:
# rm: cannot remove 'result.tsv': No such file or directory
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute x -i                                                                56s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.368
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.245
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.2075
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0033
#  - Partial Leakage: 0.3873
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute y -i                                                                42s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.3187
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4709
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.3327
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0053
#  - Partial Leakage: 0.4601
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute z -i                                                                54s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1935
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2888
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.3844
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0045
#  - Partial Leakage: 0.3882
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute t -i                                                                22s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9515
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9947
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9764
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0
#  - Partial Leakage: 0.9994
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute x                                                                   15s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: Null
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2253
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.1827
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0116
#  - Partial Leakage: 0.5537
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute y                                                                   80s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.3492
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: Null
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.3582
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 4/245000 voxels 	Average Partial Leakage 0.0404
#  - Partial Leakage: 0.6172
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute z                                                                   58s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2485
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.3463
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: Null
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0089
#  - Partial Leakage: 0.6075
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# nii permute t                                                                   46s/file]
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Original file is scrambled.
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9516
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9951
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9766
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0109
#  - Partial Leakage: 0.9994
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...

# %% [markdown]
# This is the same exact test as prevoius one, along permutaion independently only on time-axis with report.
#
# ## What to expect:
# In the report you can see the distribution plots of this test for more details, alongside minimum, maximum and average leakage along each axis. We expect to see in the plots **n** number of images which is identical to the original image, since slices are replaced from original.

# %%
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
opts = ["nii", "permute", "t -i"] 

run_test(files, opt=opts, clean=True, disp=True)
! rm result.tsv
# Out:
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     26s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9515
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9947
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9764
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0
#  - Partial Leakage: 0.9994
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 99.94%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.09&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.47</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.50</p>
#                     <p><strong>Z</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.44</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.38</p>
#                     <p><strong>Y</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.45</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 0.39</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">Temporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Temporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Wobble
# Deform the images using 3D random waveforms
#
# ## What to expect:
# We expect lesser leakage as the intensity of wobbling is higher.
#
# At the bottom, we visualize the result of **full** and **partial leakage** where x-axis shows the wobbling intensity and y-axis is leakage

# %%
opts = ["nii", "wobble", "-a ", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 
crit = np.arange(2.0, 12.5, 0.5, dtype=float)

for p in crit:
    opts[3] = str(p)
    print(opts)
    run_test(files, opt=opts, clean= False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# ['nii', 'wobble', '-a ', '2.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     01s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2623
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2928
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.2655
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0035
#  - Partial Leakage: 0.3292
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '2.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     11s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2084
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.2462
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.2224
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0024
#  - Partial Leakage: 0.28
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '3.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     13s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1368
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1736
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.1708
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0027
#  - Partial Leakage: 0.2019
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '3.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     15s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1107
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1445
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.1444
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0013
#  - Partial Leakage: 0.1659
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '4.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     15s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.086
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.1049
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.11
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0011
#  - Partial Leakage: 0.1303
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '4.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     07s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0729
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0867
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0864
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0012
#  - Partial Leakage: 0.1047
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '5.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     17s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0584
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0829
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0689
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0009
#  - Partial Leakage: 0.0892
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '5.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     41s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0518
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0576
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0517
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0013
#  - Partial Leakage: 0.0731
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '6.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     14s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0544
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0498
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0448
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.001
#  - Partial Leakage: 0.0675
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '6.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     20s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0497
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0458
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0426
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0004
#  - Partial Leakage: 0.0651
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '7.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     18s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0411
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0387
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0334
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0008
#  - Partial Leakage: 0.0573
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '7.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     25s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0443
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0476
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0401
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0012
#  - Partial Leakage: 0.0645
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '8.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     09s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0426
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0463
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0357
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0011
#  - Partial Leakage: 0.0553
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '8.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     96s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0433
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0417
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0383
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.001
#  - Partial Leakage: 0.0635
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '9.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     09s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0449
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.044
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0348
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0006
#  - Partial Leakage: 0.0669
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '9.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     40s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0396
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0508
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.037
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0007
#  - Partial Leakage: 0.0597
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '10.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     39s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0445
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0416
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0342
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.001
#  - Partial Leakage: 0.0607
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '10.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     30s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0432
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.042
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0312
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0002
#  - Partial Leakage: 0.0595
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '11.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     31s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0452
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0393
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0344
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0008
#  - Partial Leakage: 0.0585
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '11.5']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     36s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0362
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0453
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0306
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0009
#  - Partial Leakage: 0.0537
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ['nii', 'wobble', '-a ', '12.0']
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     42s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0447
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0388
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.0293
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0011
#  - Partial Leakage: 0.0549
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.

# %%
opts = ["nii", "wobble", "-a ", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
! rm result.tsv
# Out:
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     30s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0704
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.0705
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.063
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0011
#  - Partial Leakage: 0.0905
#  - Full Leakage: False
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 9.05%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: -0.07&emsp;&emsp;&emsp;Max: 0.10&emsp;&emsp;&emsp;AVG: 0.01</p>
#                     <p><strong>Y</strong>: Min: -0.03&emsp;&emsp;&emsp;Max: 0.09&emsp;&emsp;&emsp;AVG: 0.02</p>
#                     <p><strong>Z</strong>: Min: -0.02&emsp;&emsp;&emsp;Max: 0.08&emsp;&emsp;&emsp;AVG: 0.03</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: -0.06&emsp;&emsp;&emsp;Max: 0.11&emsp;&emsp;&emsp;AVG: 0.03</p>
#                     <p><strong>Y</strong>: Min: -0.01&emsp;&emsp;&emsp;Max: 0.11&emsp;&emsp;&emsp;AVG: 0.04</p>
#                     <p><strong>Z</strong>: Min: 0.00&emsp;&emsp;&emsp;Max: 0.10&emsp;&emsp;&emsp;AVG: 0.04</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">Temporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Temporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Method: Scatter

# %%
! rm result.tsv
opts = ["nii", "scatter", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled]
crit = np.arange(3, 13.5, 0.5, dtype=float)

for p in crit:
    opts[2] = str(p)
    run_test(files, opt=opts, clean= True)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# rm: cannot remove 'result.tsv': No such file or directory
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 1]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     22s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.7546
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.82
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.8228
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0196
#  - Partial Leakage: 0.9291
#  - Full Leakage: False
#
# Total time taken: 00:00:36
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     85s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.6618
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.7295
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.7258
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0194
#  - Partial Leakage: 0.8574
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [2 2 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     44s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.6616
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.7294
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.7254
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0196
#  - Partial Leakage: 0.8572
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 2]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     35s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5576
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.6316
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.6173
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0193
#  - Partial Leakage: 0.7851
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     88s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4745
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5471
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.5591
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0191
#  - Partial Leakage: 0.7223
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     29s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4754
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5476
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.5593
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0195
#  - Partial Leakage: 0.7224
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 3]                                                                  ?file/s]
# step: [2, 2, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     03s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5768
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.636
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.6012
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0741
#  - Partial Leakage: 0.9902
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 3]                                                                  ?file/s]
# step: [2, 2, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     99s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5768
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.6358
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.6012
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0744
#  - Partial Leakage: 0.9903
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [4 4 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     00s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5574
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.6165
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.594
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0938
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     89s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4328
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4999
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.5174
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0398
#  - Partial Leakage: 0.6992
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 4]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     97s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.433
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.5178
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0401
#  - Partial Leakage: 0.6993
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [5 5 5]                                                                  ?file/s]
# step: [2, 2, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     37s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.3739
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4423
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4257
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0188
#  - Partial Leakage: 0.507
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 5]                                                                  ?file/s]
# step: [3, 3, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     26s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4085
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4759
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.498
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0204
#  - Partial Leakage: 0.6794
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 5]                                                                  ?file/s]
# step: [3, 3, 2]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     32s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4085
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4756
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4978
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0207
#  - Partial Leakage: 0.6786
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [6 6 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     65s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.3952
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4639
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4975
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0401
#  - Partial Leakage: 0.67
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     29s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4611
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4958
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4423
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.1206
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     54s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4612
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4958
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4427
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.1207
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [7 7 6]                                                                  ?file/s]
# step: [3, 3, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     61s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4614
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4954
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4423
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.1207
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     58s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4318
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4654
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.425
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0753
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     40s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4316
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4654
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4252
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0753
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [8 8 7]                                                                  ?file/s]
# step: [4, 4, 3]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     25s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4317
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.4651
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.4248
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0752
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# Cleaning up ...

# %%
opts = ["nii", "scatter", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
! rm result.tsv
# Out:
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# window: [3 3 3]                                                                  ?file/s]
# step: [1, 1, 1]
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     46s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.475
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.5473
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.5594
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.0192
#  - Partial Leakage: 0.7217
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 20px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Original image" onclick="showModal(this.src)">
#                 <h3>Original image</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Scrambled image" onclick="showModal(this.src)">
#                 <h3>Scrambled image</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 72.17%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.04&emsp;&emsp;&emsp;Max: 0.57&emsp;&emsp;&emsp;AVG: 0.28</p>
#                     <p><strong>Y</strong>: Min: 0.13&emsp;&emsp;&emsp;Max: 0.61&emsp;&emsp;&emsp;AVG: 0.37</p>
#                     <p><strong>Z</strong>: Min: 0.05&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.36</p>
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>X</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 0.57&emsp;&emsp;&emsp;AVG: 0.23</p>
#                     <p><strong>Y</strong>: Min: 0.03&emsp;&emsp;&emsp;Max: 0.61&emsp;&emsp;&emsp;AVG: 0.33</p>
#                     <p><strong>Z</strong>: Min: 0.01&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.31</p>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Spatial Analysis section -->
#     <h2 style="margin-top: 60px; text-align: center;">Spatial Analysis</h2>
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="x dim" onclick="showModal(this.src)">
#             <h3>x dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="y dim" onclick="showModal(this.src)">
#             <h3>y dim</h3>
#         </div>
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="z dim" onclick="showModal(this.src)">
#             <h3>z dim</h3>
#         </div>
#     </div>
#
#     <!-- Spatiotemporal Analysis section (conditional) -->
#
#     <h2 style="margin-top: 60px; text-align: center;">Temporal Analysis</h2>
#     <div class="image-row" style="justify-content: center;">
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Temporal Analysis" onclick="showModal(this.src)">
#             <h3>SpatioTemporal Analysis</h3>
#         </div>
#     </div>
#
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Blur
# Applies a 3D Gaussian smoothing filter. This method removes details and noise to blur the image.
#
# ## What to expect:
# We expect to see less partial leakage as the intensity of the blurring increases, and perhaps full leakage when blurring is at the lowest level.

# %%
opts = ["nii", "blur", "_"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 
crit = np.arange(2.0, 12.0, 1.0, dtype=float)

for p in crit:
    opts[2] = str(p)
    run_test(files, opt=opts, clean= False)

with open("result.tsv", "r") as file:
    f = csv.reader(file, delimiter="\t")
    f = [row for row in f]
        
viz(f,crit)
! rm result.tsv
# Out:
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     16s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 1.0
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: Null
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 1.0
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage Null
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     18s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9959
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9983
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9971
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.9872
#  - Partial Leakage: 0.999
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     82s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9713
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9883
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9778
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.8732
#  - Partial Leakage: 0.993
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     93s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9438
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9765
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9591
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.698
#  - Partial Leakage: 0.9858
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     89s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9239
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.966
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9453
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.5554
#  - Partial Leakage: 0.9794
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     24s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9094
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9564
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.932
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.4553
#  - Partial Leakage: 0.9733
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     97s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.8974
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9471
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.92
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.3844
#  - Partial Leakage: 0.9676
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     60s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.8872
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9387
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.9089
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.3322
#  - Partial Leakage: 0.9622
#  - Full Leakage: False
#
# Total time taken: 00:00:35
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     15s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.8781
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9304
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.8983
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.2923
#  - Partial Leakage: 0.9571
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# 100% [....................................................] 60545196 / 60545196
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/func/scrambled/sub-SAXNES2s001_task-DOTS_run-001_bold.nii.gz
# Original file is scrambled.                                                     25s/file]
# ########################################
#  - Subject ID: sub-SAXNES2s001
#  - Task: DOTS
#  - Run: run-001
#  - Shape: (70, 70, 50, 248)
# ########################################
#  - Spatial Analysis
#  - Averaged over time dimension
# 	 - Dimension[X]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.8698
# 	 - Dimension[Y]: 	Full Leakage: 0/70 slices	Average Partial Leakage: 0.9222
# 	 - Dimension[Z]: 	Full Leakage: 0/50 slices	Average Partial Leakage: 0.8895
#  - Temporal voxel-wise Analysis
# 	 - Total voxels: 245000 of shape (1, 1, 1, 248)
# 	 - Temporal: 	Full Leakage: 0/245000 voxels 	Average Partial Leakage 0.2609
#  - Partial Leakage: 0.9522
#  - Full Leakage: False
#
# Total time taken: 00:00:34
#
# Analysis is finished.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 15
#      12     f = csv.reader(file, delimiter="\t")
#      13     f = [row for row in f]
# ---> 15 viz(f,crit)
#      16 get_ipython().system(' rm result.tsv')
#
# Cell In[2], line 7, in viz(f, crit)
#       3 fl = [int(x[1]) for x in f]
#       5 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
# ----> 7 ax1.plot(list(crit),pl, color='skyblue')
#       8 ax1.set_title("Partial Leakage")
#       9 ax1.set_xlabel("Scrambling parameter")
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/fsl6.0.7/lib/python3.11/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (22,)

# %%
opts = ["nii", "blur", "5"]
original = "input/func/original/"
scrambled = "input/func/scrambled/"
files = [original, scrambled] 

run_test(files, opt=opts, clean=True, disp=True)
