# %% [markdown]
# In this notebook you'll find a range of tests showcasing how leakage is detected using our repostory.
# This notebook is divided into two sections where each section is analyzing one type of data.
#
# ## Data
# Two different images of type MEG (Magnetoencephalography) and EEG (Electroencephalography) has been analyzed in this notebook. Each time you run a test will be downloaded and deleted at the end. Read more about MEG data in this [link](https://openneuro.org/datasets/ds000117/versions/1.0.6) and EEG data in this [link](https://osf.io/thsqg/).
#
#
# ## Methods:
# We have tested the leakage score using three known methods.
# - [[Pearson correlation]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Pearson_correlation_coefficient&ved=2ahUKEwic1fmek9KNAxVp2QIHHef7MlIQFnoECDMQAQ&usg=AOvVaw0oS2sNVkApYvcS_BsC8s3p): A mathematical correlation coefficient representing the relationship between one 2D slice of original vs. corresponding scrambled 2D slice.
# - Structural Similarity Index Measure[[SSIM]](https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://en.wikipedia.org/wiki/Structural_similarity_index_measure&ved=2ahUKEwjWrMKvktKNAxUR1QIHHcsFMcsQFnoECBAQAQ&usg=AOvVaw0DeKf5zozxPyKboaovBeRN): A perceptual metric that quantifies image quality degradation caused by scrambling.
# - Identical[[np.allclose]](https://numpy.org/doc/2.1/reference/generated/numpy.allclose.html): Searches for exact identical arrays of voxels
# ## What to expect:
# - At the bottom of each test, we visualize either plots to track leakage or a report inlcuding basic descriptive statistics with distribution plots.
# - The x-axis in the plots shows scrambling parameter, and y-axis shows leakage score.
#
# ## List of tests:
# - Original Vs. Original
# - Permutation
# - Permutation - channel & time

# %%
import os, sys, subprocess, csv, random, wget, shutil
import numpy as np
from IPython.display import HTML, display
import matplotlib.pyplot as plt

# %%
def viz(f, crit): 
    pl = [float(x[0]) for x in f]
    fl = [int(x[1]) for x in f]
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    ax1.plot(list(crit),pl, color='skyblue')
    ax1.set_title("Partial Leakage")
    ax1.set_xlabel("Scrambling parameter")
    ax1.set_ylabel("Leakage score")
    ax2.plot(list(crit),fl, color='skyblue')
    ax2.set_title("Full Leakage")
    ax2.set_xlabel("Scrambling parameter")
    
    plt.tight_layout()
    plt.show()

def run_test(files=list, opt=list, scramble=True, clean=True, disp=False):
    
    os.makedirs("img", exist_ok=True)
    link_original = "https://s3.amazonaws.com/openneuro.org/ds000117/sub-01/ses-meg/meg/sub-01_ses-meg_task-facerecognition_run-01_meg.fif?versionId=RYisEgBpM3WNBoVpb2qE2EXs4oNJFn3x"
    wget.download(link_original)
    os.makedirs("input/original", exist_ok=True)
    file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()) for file in files if file.endswith(".fif")]
    shutil.copy2(file_[0], "input/original")
    os.remove(file_[0])
    print(f"\nOriginal file downloaded.")
    script = os.path.join(os.path.dirname(os.getcwd()), "run_test.py")
    original = files[0]
    scrambled = files[1]
    params = {
        "input": original,
        "output": scrambled,
        "opts": opts
    }
    if scramble:
        ! scramble "{params['input']}" "{params['output']}" {" ".join(params['opts'])}
    print(f"\nOriginal file is scrambled.")
    result= subprocess.run(
        ["python3", script, original, scrambled, "True"],
        capture_output=True,
        text=True
    )
    print(f"Analysis is finished.")
    print(result.stdout)
    if disp:
        file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()+"/report/") for file in files if file.endswith(".html")]
        with open(file_[0]) as f:
            display(HTML(f.read()))
  
    print(f"Cleaning up ...")    
    if clean:
        ! rm -r input report img

# %% [markdown]
# # MEG Usecase-2.3

# %% [markdown]
# # Original Vs. Original
# We test the same original image and we expect to see full leakage.
#
# For more details, we can check the visualization where you can see the distribution of identicals.
# ## What to expect:
# Since we're passing the same image and consider it as scramble, we expect to see identified full leakage, and the distribution plots in each axis should show **n** number of slices that is identical. **n** is equal to the number of images each axis contains.

# %%
original = "input/original/"
scrambled = "input/scrambled/"
opts = ["fif", "permute", "time"] # This will NOT be used, but needs to pass
files = [original, original]
run_test(files, scramble=False, clean=False, disp=True) # NOTE: If original vs. original, then clean=False, otherwise original file gets deleted.
# Out:
# 100% [..................................................] 860240688 / 860240688
# Original file downloaded.
#
# Original file is scrambled.
# Analysis is finished.
# ########################################
#  - Subject ID: sub-01
#  - Task: facerecognition
#  - Run: run-01
#  - Shape: (395, 540100)
# ########################################
# 	 - Temporal: 	Full Leakage: 393/395 channels 	Average Partial Leakage Null
#  - Partial Leakage: Null
#  - Full Leakage: True
#  - Please consider applying scramble on your dataset again.
#
# Total time taken: 00:00:32
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 60px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Original]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Original]</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Scrambled]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Scrambled]</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> True</p>
#                 <p><strong>Partial leakage:</strong> 100.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: 1.00&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 1.00</p>
#                 <!--
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: 1.00&emsp;&emsp;&emsp;Max: 1.00&emsp;&emsp;&emsp;AVG: 1.00</p>
#
#                 -->
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Bottom row of small images -->
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Time Dimension" onclick="showModal(this.src)">
#             <h3>Time Dimension</h3>
#         </div>
#     </div>
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # Method: Permutation
# In this case we **permute** the image to see how scramble affect the leakage.
# Permutation is done in two different ways.
#
# - Independently where we pass **-i** as argument, which all arrays in the given axis are permuted independently.
# - Without **-i** the given axis remain as it is, while other axis are permuted.
#
# We test permutation on each axis w/o passing **-i** as argument

# %%
original = "input/original/"
scrambled = "input/scrambled/"
files = [original, scrambled]
opts = ["fif", "permute", "channel", "time"] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [..................................................] 860240688 / 860240688
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
#   0%|                                                   | 0/1 [00:00<?, ?file/s]Opening raw data file /indirect/staff/vincentajoubi/Don't look/DL/test/input/original/sub-01_ses-meg_task-facerecognition_run-01_meg.fif...
#     Read a total of 8 projection items:
#         mag_ssp_upright.fif : PCA-mags-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v5 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v3 (1 x 306)  idle
#     Range : 248600 ... 788699 =    226.000 ...   716.999 secs
# Ready.
# Reading 0 ... 540099  =      0.000 ...   490.999 secs...
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
#   0%|                                                   | 0/1 [00:07<?, ?file/s]Writing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# Closing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# [done]
#                                                                             39s/file]
# Original file is scrambled.
# Analysis is finished.
# ########################################
#  - Subject ID: sub-01
#  - Task: facerecognition
#  - Run: run-01
#  - Shape: (395, 540100)
# ########################################
# 	 - Temporal: 	Full Leakage: 0/395 channels 	Average Partial Leakage -0.0001
#  - Partial Leakage: 0.0054
#  - Full Leakage: False
#
# Total time taken: 00:00:25
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 60px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Original]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Original]</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Scrambled]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Scrambled]</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 0.54%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: -0.00&emsp;&emsp;&emsp;Max: 0.01&emsp;&emsp;&emsp;AVG: -0.00</p>
#                 <!--
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: 0.00&emsp;&emsp;&emsp;Max: 0.07&emsp;&emsp;&emsp;AVG: 0.01</p>
#
#                 -->
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Bottom row of small images -->
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Time Dimension" onclick="showModal(this.src)">
#             <h3>Time Dimension</h3>
#         </div>
#     </div>
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %%
original = "input/original/"
scrambled = "input/scrambled/"
files = [original, scrambled]
opts = ["fif", "permute", "time"] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [..................................................] 860240688 / 860240688
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
#   0%|                                                   | 0/1 [00:00<?, ?file/s]Opening raw data file /indirect/staff/vincentajoubi/Don't look/DL/test/input/original/sub-01_ses-meg_task-facerecognition_run-01_meg.fif...
#     Read a total of 8 projection items:
#         mag_ssp_upright.fif : PCA-mags-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v5 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v3 (1 x 306)  idle
#     Range : 248600 ... 788699 =    226.000 ...   716.999 secs
# Ready.
# Reading 0 ... 540099  =      0.000 ...   490.999 secs...
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
#   0%|                                                   | 0/1 [00:19<?, ?file/s]Writing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# Closing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# [done]
#                                                                             81s/file]
# Original file is scrambled.
# Analysis is finished.
# ########################################
#  - Subject ID: sub-01
#  - Task: facerecognition
#  - Run: run-01
#  - Shape: (395, 540100)
# ########################################
# 	 - Temporal: 	Full Leakage: 0/395 channels 	Average Partial Leakage -0.0008
#  - Partial Leakage: 0.0031
#  - Full Leakage: False
#
# Total time taken: 00:00:25
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 60px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Original]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Original]</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Scrambled]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Scrambled]</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 0.31%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: -0.00&emsp;&emsp;&emsp;Max: 0.00&emsp;&emsp;&emsp;AVG: -0.00</p>
#                 <!--
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: 0.00&emsp;&emsp;&emsp;Max: 0.45&emsp;&emsp;&emsp;AVG: 0.02</p>
#
#                 -->
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Bottom row of small images -->
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Time Dimension" onclick="showModal(this.src)">
#             <h3>Time Dimension</h3>
#         </div>
#     </div>
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# Here we **permute** only channels, but not brainwave information.
#
# ### What to expect
# Since brainwave information is not touched, we expect to see identical channels, or eventually full leakage. If not perhaps high partial leakage which can only be seen in the report plots.

# %%
original = "input/original/"
scrambled = "input/scrambled/"
files = [original, scrambled]
opts = ["fif", "permute", "channel"] 

run_test(files, opt=opts, clean=True, disp=True)
# Out:
# 100% [..................................................] 860240688 / 860240688
# Original file downloaded.
# Found 1 input files and 0 directories using '(?!\.).*'
#   0%|                                                   | 0/1 [00:00<?, ?file/s]Opening raw data file /indirect/staff/vincentajoubi/Don't look/DL/test/input/original/sub-01_ses-meg_task-facerecognition_run-01_meg.fif...
#     Read a total of 8 projection items:
#         mag_ssp_upright.fif : PCA-mags-v1 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v2 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v3 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v4 (1 x 306)  idle
#         mag_ssp_upright.fif : PCA-mags-v5 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v1 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v2 (1 x 306)  idle
#         grad_ssp_upright.fif : PCA-grad-v3 (1 x 306)  idle
#     Range : 248600 ... 788699 =    226.000 ...   716.999 secs
# Ready.
# Reading 0 ... 540099  =      0.000 ...   490.999 secs...
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
#   0%|                                                   | 0/1 [00:03<?, ?file/s]Writing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# Closing /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-01_ses-meg_task-facerecognition_run-01_meg.fif
# [done]
#                                                                             42s/file]
# Original file is scrambled.
# Analysis is finished.
# ########################################
#  - Subject ID: sub-01
#  - Task: facerecognition
#  - Run: run-01
#  - Shape: (395, 540100)
# ########################################
# 	 - Temporal: 	Full Leakage: 0/395 channels 	Average Partial Leakage 0.03
#  - Partial Leakage: 0.03
#  - Full Leakage: False
#
# Total time taken: 00:00:24
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 60px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Original]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Original]</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Scrambled]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Scrambled]</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 3.00%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: -0.98&emsp;&emsp;&emsp;Max: 0.98&emsp;&emsp;&emsp;AVG: 0.03</p>
#                 <!--
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: -0.95&emsp;&emsp;&emsp;Max: 0.97&emsp;&emsp;&emsp;AVG: 0.04</p>
#
#                 -->
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Bottom row of small images -->
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Time Dimension" onclick="showModal(this.src)">
#             <h3>Time Dimension</h3>
#         </div>
#     </div>
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...

# %% [markdown]
# # EEG Usecase-2.4

# %% [markdown]
# # Method: Permutation
# In this case we **permute** the EEG (brainwave) recordings as input. There exist only time dimension, which is the only axis available to permute.
#
# ## What to expect
# Since we randomly shuffling the time information, we expect to see no full leakage or identical brainwaves. However there can be likelihood of partial leakage since shuffling is based on randomness.

# %%
import zipfile, mne, warnings
warnings.filterwarnings("ignore")

# %%
link_original = "https://files.osf.io/v1/resources/q6gwp/providers/osfstorage/600df66775226b018251568f/?zip="
wget.download(link_original)
print(f"\nFile is downloaded")
os.makedirs("input/original/tmp", exist_ok=True)

with zipfile.ZipFile("eeg.zip", 'r') as zip_:
    zip_.extractall("input/original/tmp")
raw = mne.io.read_raw_eeglab('input/original/tmp/sub-002_task-ERN_eeg.set', preload=True)
raw.export('input/original/sub-002_task-ERN_eeg.vhdr', 
     fmt='brainvision',
     overwrite=True)
! rm eeg.zip
! rm -r input/original/tmp
print("File is converted to BrainVision")

original = "input/original/"
scrambled = "input/scrambled/"
files = [original, scrambled]
opts = ["brainvision", "permute"]
params = {
        "input": original,
        "output": scrambled,
        "opts": opts
    }
! scramble "{params['input']}" "{params['output']}" {" ".join(params['opts'])}
print("File is scrambled")
# Out:
# -1 / unknown
# File is downloaded
# Reading /indirect/staff/vincentajoubi/Don't look/DL/test/input/original/tmp/sub-002_task-ERN_eeg.fdt
# Reading 0 ... 900095  =      0.000 ...   878.999 secs...
# File is converted to BrainVision
# Found 1 input files and 0 directories using '(?!\.).*'
# Saving: /indirect/staff/vincentajoubi/Don't look/DL/test/input/scrambled/sub-002_task-ERN_eeg.vhdr
# File is scrambled                                                               08s/file]

# %%
os.makedirs("img", exist_ok=True)
script = os.path.join(os.path.dirname(os.getcwd()), "run_test.py")
result= subprocess.run(
        ["python3", script, original, scrambled, "True"],
        capture_output=True,
        text=True)

print(f"Analysis is finished.")
print(result.stdout)
# Out:
# Analysis is finished.
# ########################################
#  - Subject ID: sub-002
#  - Task: ERN
#  - Session: ERN
#  - Shape: (33, 900096)
# ########################################
# 	 - Temporal: 	Full Leakage: 0/33 channels 	Average Partial Leakage 0.0003
#  - Partial Leakage: 0.002
#  - Full Leakage: False
#
# Total time taken: 00:00:11

# %%
file_ = [os.path.join(root, file) for root, _, files in os.walk(os.getcwd()+"/report/") for file in files if file.endswith(".html")]
with open(file_[0]) as f:
    display(HTML(f.read()))

print(f"Cleaning up ...")    
! rm -r input report img
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Embedded Correlation Report</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 40px;
#             background-color: #f9f9f9;
#         }
#         h1 {
#             text-align: center;
#             margin-bottom: 40px;
#         }
#         .top-container {
#             display: flex;
#             justify-content: space-between;
#             gap: 30px;
#             margin-bottom: 60px;
#         }
#         .top-row {
#             display: flex;
#             justify-content: space-around;
#             gap: 30px;
#             flex: 2;
#         }
#         .top-box {
#             flex: 1;
#             text-align: center;
#         }
#         .top-box img {
#             width: 100%;
#             max-width: 400px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .top-box h3 {
#             margin-top: 10px;
#             font-size: 18px;
#             color: #333;
#         }
#         .stats-container {
#             flex: 1;
#             min-width: 300px;
#         }
#         .image-row {
#             display: flex;
#             justify-content: space-around;
#             align-items: flex-start;
#             gap: 20px;
#             margin-top: 60px;
#         }
#         .image-box {
#             flex: 1;
#             text-align: center;
#         }
#         .image-box img {
#             width: 100%;
#             max-width: 600px;
#             height: auto;
#             border: 1px solid #ccc;
#             box-shadow: 2px 2px 8px rgba(0,0,0,0.1);
#             cursor: zoom-in;
#         }
#         .image-box h3 {
#             margin-top: 10px;
#             font-size: 16px;
#             color: #333;
#         }
#         /* Stats section */
#         .stats {
#             margin-top: 0;
#             padding: 15px;
#             background-color: #f8f8f8;
#             border: 1px solid #ddd;
#             border-radius: 5px;
#             font-family: monospace;
#             font-size: 16px;
#             line-height: 1.6;
#             height: 100%;
#             box-sizing: border-box;
#         }
#
#         .leakage-details {
#             margin-left: 20px;
#             padding-left: 10px;
#             border-left: 2px solid #ddd;
#         }
#
#         .stats h3 {
#             color: #333;
#             margin: 10px 0;
#         }
#
#         .stats p {
#             margin: 5px 0;
#             font-family: monospace;
#         }
#         /* Lightbox modal */
#         .modal {
#             display: none;
#             position: fixed;
#             z-index: 10;
#             left: 0; top: 0;
#             width: 100%; height: 100%;
#             overflow: auto;
#             background-color: rgba(0,0,0,0.9);
#         }
#         .modal-content {
#             margin: auto;
#             display: block;
#             max-width: 90%;
#             max-height: 90%;
#         }
#         .close {
#             position: absolute;
#             top: 20px; right: 35px;
#             color: white;
#             font-size: 40px;
#             font-weight: bold;
#             cursor: pointer;
#         }
#         @keyframes zoom {
#             from {transform: scale(0.7)}
#             to {transform: scale(1)}
#         }
#         .modal-content, .modal {
#             animation: zoom 0.3s;
#         }
#     </style>
# </head>
# <body>
#     <h1>Leakage Analysis Report</h1>
#
#     <!-- Top container with images and stats -->
#     <div class="top-container">
#         <!-- Top side-by-side images -->
#         <div class="top-row">
#
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Original]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Original]</h3>
#             </div>
#             <div class="top-box">
#                 <img src="data:image/png;base64,..." alt="Power Spectral Density [Scrambled]" onclick="showModal(this.src)">
#                 <h3>Power Spectral Density [Scrambled]</h3>
#             </div>
#         </div>
#
#         <!-- Stats section -->
#         <div class="stats-container">
#             <div class="stats">
#                 <h3>Result:</h3>
#                 <p><strong>Full leakage:</strong> False</p>
#                 <p><strong>Partial leakage:</strong> 0.20%</p>
#                 <p><strong>Pearson Correlation:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: -0.00&emsp;&emsp;&emsp;Max: 0.00&emsp;&emsp;&emsp;AVG: 0.00</p>
#                 <!--
#                 </div>
#                 <p><strong>SSIM Score:</strong></p>
#                 <div class="leakage-details">
#                     <p><strong>Time Dimension</strong>: Min: 0.00&emsp;&emsp;&emsp;Max: 0.04&emsp;&emsp;&emsp;AVG: 0.01</p>
#
#                 -->
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Bottom row of small images -->
#     <div class="image-row">
#
#         <div class="image-box">
#             <img src="data:image/png;base64,..." alt="Time Dimension" onclick="showModal(this.src)">
#             <h3>Time Dimension</h3>
#         </div>
#     </div>
#
#     <!-- Lightbox modal -->
#     <div id="imgModal" class="modal" onclick="closeModal()">
#         <span class="close">&times;</span>
#         <img class="modal-content" id="modalImage">
#     </div>
#
#     <script>
#         function showModal(src) {
#             const modal = document.getElementById("imgModal");
#             const modalImg = document.getElementById("modalImage");
#             modal.style.display = "block";
#             modalImg.src = src;
#         }
#         function closeModal() {
#             document.getElementById("imgModal").style.display = "none";
#         }
#     </script>
# </body>
# </html>
# Cleaning up ...
